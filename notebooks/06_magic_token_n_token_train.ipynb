# %% [markdown]
# ## This model attempts to find n embeddings to make gpt2 produce scripture without modifying the model

# %%
import os, torch, pickle
from ipywidgets import Dropdown
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch.nn.functional as F
from torch.optim import SGD
import torch.nn as nn

# %%
trained_model_folder = "./out"
language_pair_staging_folder = "../data/magic_token_folder/"
num_magic_tokens = 1
trained_embeddings_pickle_file = os.path.join( language_pair_staging_folder, f"magic_tokens_size_{num_magic_tokens}.pickle" )

# %%
selected_langauge = "bsb"

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("No GPU available, using CPU.")


def load_model(model_path):
    model = GPT2LMHeadModel.from_pretrained(model_path).to(device)
    return model


def load_tokenizer(tokenizer_path):
    tokenizer = GPT2Tokenizer.from_pretrained(tokenizer_path)
    return tokenizer


def grab_line_from_file( file, index ):
    n = 0
    with open( file, "rt" ) as fin:
        for line in fin:
            if n == index:
                return line.strip()
            n += 1

def get_index_from_training_file( index ):
    training_file = os.path.join( language_pair_staging_folder, 
                                 f"train_{selected_langauge}.txt" )
    return grab_line_from_file( training_file, index )

def split_off_magic_tokens( verse ):
    magic_tokens = []
    start = 0
    iterator = 0
    while iterator < len(verse):
        if verse[iterator] == "]":
            magic_tokens.append( verse[start:iterator+1] )
            start = iterator+1
        iterator += 1
    return magic_tokens, verse[start:]

def change_number_of_magic_tokens( magic_tokens, new_number ):
    return [ magic_tokens[0][:-2] + chr(i + ord('a')) + "]" for i in range(new_number) ]

def save_to_pickle( learned_magic_tokens ):
    with open( trained_embeddings_pickle_file, "wb" ) as fout:
        pickle.dump( learned_magic_tokens, fout )
# Out:
# Using GPU: NVIDIA GeForce RTX 2080

# %%
split_off_magic_tokens( "[hi][how]are you today?" )
# Out:
# (['[hi]', '[how]'], 'are you today?')

# %%
change_number_of_magic_tokens( ["[GEN 1:1_a]","[GEN 1:1_b]"], 4 )
# Out:
# ['[GEN 1:1_a]', '[GEN 1:1_b]', '[GEN 1:1_c]', '[GEN 1:1_d]']

# %%
tokenizer = load_tokenizer( "gpt2" )

# %%
model = load_model( "gpt2" )

# %%
zero_index = torch.LongTensor([0]).to(device)

# %%
#as I won't be useing an expanded tokenizer or model for this experiment we will need to store these embeddings in a dictionary
learned_magic_tokens = {}

# %%
if os.path.exists(trained_embeddings_pickle_file):
    with open(trained_embeddings_pickle_file, 'rb') as file:
        learned_magic_tokens = pickle.load(file)
        print( f"Loaded previouse training from {trained_embeddings_pickle_file}" )
else:
    print( f"Previouse training not found at {trained_embeddings_pickle_file}" )
# Out:
# Loaded previouse training from ../data/magic_token_folder/magic_tokens_size_1.pickle

# %%
#Init the iteration here so that we can start and stop the following cell without starting over.
verse_number = 0

# %%
while get_index_from_training_file( verse_number ) != None:
    verse_with_magic_tokens = get_index_from_training_file( verse_number )
    print( f"\n\nWorking on verse {verse_with_magic_tokens}" )
    #remove the magic tokens from the verse because the tokenizer won't know what to do with them.
    magic_tokens, verse = split_off_magic_tokens( verse_with_magic_tokens )

    #verse = "I love to eat chicken."
    #make it so that we can play with a different number of magic tokens then is in the training file.
    #make it so that we can play with a different number of magic tokens then is in the training file.
    magic_tokens = change_number_of_magic_tokens( magic_tokens, num_magic_tokens )
    tokenized = tokenizer( verse )
    
    #control_embeddings_weights = model.get_input_embeddings().weight.detach()
    #control_embeddings = nn.Embedding.from_pretrained( control_embeddings_weights )

    slope = -.05

    
    for run in range( 100 ):
        model.zero_grad()
        print( f"\n{run}: ", end='' )

        # if( magic_tokens[0] in learned_magic_tokens ):
        #     print( f"\n First couple learned values of magic token 0: {learned_magic_tokens[magic_tokens[0]][:5]}", end='' )

        found_problem = False
        
        for token_to_teach in range( len(tokenized["input_ids"]) ):
    
            input_ids = torch.LongTensor(tokenized["input_ids"][:token_to_teach])
            correct_token = tokenized["input_ids"][token_to_teach]
            target_tensor = torch.zeros(len(tokenizer)).to(device)
            target_tensor[correct_token] = 25.0

            inputs_embeds_list = []
            for magic_token in magic_tokens:
                if not magic_token in learned_magic_tokens:
                    learned_magic_tokens[magic_token] = torch.randn_like( model.get_input_embeddings()(zero_index)[0] )
                    learned_magic_tokens[magic_token].requires_grad = True
                    learned_magic_tokens[magic_token].retain_grad()
                inputs_embeds_list.append( learned_magic_tokens[magic_token] )
            for input_index in range(token_to_teach):
                inputs_embeds_list.append( model.get_input_embeddings()( torch.LongTensor([tokenized["input_ids"][input_index]]).to(device) )[0] )
                
            
            inputs_embeds = torch.stack(inputs_embeds_list, dim=0).to(device)
            #inputs_embeds.requires_grad = True
            #inputs_embeds.retain_grad()
            result = model.forward( inputs_embeds = inputs_embeds )
            loss = F.cross_entropy( result.logits[-1].unsqueeze(0), target_tensor.unsqueeze(0) )
            loss.backward()
        
            probs = F.softmax(result.logits[-1], dim=-1)
            #sampled_token_id = torch.multinomial(probs, 1).item()
            sampled_token_id = torch.argmax(probs, dim=-1).item()
            print(tokenizer.decode( [sampled_token_id] ), end='')
    
            if sampled_token_id != correct_token:
                found_problem = True
                print( f"\nbreaking because {tokenizer.decode([sampled_token_id])} != {tokenizer.decode([correct_token])}" )
                break
        
        # new_inputs_embeds = inputs_embeds + (inputs_embeds.grad * slope)

        # for magic_token_i in range(len(magic_tokens)):
        #     magic_token = magic_tokens[magic_token_i]
        #     learned_magic_tokens[magic_token] = new_inputs_embeds[magic_token_i].detach()

        for magic_token_i in range(len(magic_tokens)):
            magic_token = magic_tokens[magic_token_i]
            new_magic_token_tensor = (learned_magic_tokens[magic_token] + (learned_magic_tokens[magic_token].grad * slope)).detach()
            new_magic_token_tensor.requires_grad = True
            new_magic_token_tensor.retain_grad()
            learned_magic_tokens[magic_token] = new_magic_token_tensor

        if not found_problem: break

    save_to_pickle( learned_magic_tokens )
    verse_number += 1

save_to_pickle( learned_magic_tokens )
# Out:
# Working on verse [GEN 2:13_a][GEN 2:13_b] The name of the second river is Gihon; it winds through the whole land of Cush.
#
# 0:  The "
# breaking because  " !=  name
#
# 1:  The.
# breaking because . !=  name
#
# 2:  The.
# breaking because . !=  name
#
# 3:  The.
# breaking because . !=  name
#
# 4:  The.
# breaking because . !=  name
#
# 5:  The
#
# breaking because
#  !=  name
#
# 6:  The,
# breaking because , !=  name
#
# 7:  The name,
# breaking because , !=  of
#
# 8:  The name,
# breaking because , !=  of
#
# 9:  The name,
# breaking because , !=  of
#
# 10:  The name,
# breaking because , !=  of
#
# 11:  The name,
# breaking because , !=  of
#
# 12:  The name,
# breaking because , !=  of
#
# 13:  The name,
# breaking because , !=  of
#
# 14:  The name,
# breaking because , !=  of
#
# 15:  The name,
# breaking because , !=  of
#
# 16:  The name,
# breaking because , !=  of
#
# 17:  The name,
# breaking because , !=  of
#
# 18:  The name name
# breaking because  name !=  of
#
# 19:  The name,
# breaking because , !=  of
#
# 20:  The name of the the
# breaking because  the !=  second
#
# 21:  The name of the the
# breaking because  the !=  second
#
# 22:  The name name
# breaking because  name !=  of
#
# 23:  The name name
# breaking because  name !=  of
#
# 24:  The name name
# breaking because  name !=  of
#
# 25:  The name name
# breaking because  name !=  of
#
# 26:  The name of the name
# breaking because  name !=  second
#
# 27:  The name of the name
# breaking because  name !=  second
#
# 28:  The name of the name
# breaking because  name !=  second
#
# 29:  The name of the name
# breaking because  name !=  second
#
# 30:  The name of the name
# breaking because  name !=  second
#
# 31:  The name of the name
# breaking because  name !=  second
#
# 32:  The name of the name
# breaking because  name !=  second
#
# 33:  The name of the name
# breaking because  name !=  second
#
# 34:  The name of the name
# breaking because  name !=  second
#
# 35:  The name of the name
# breaking because  name !=  second
#
# 36:  The name of the name
# breaking because  name !=  second
#
# 37:  The name of the name
# breaking because  name !=  second
#
# 38:  The name of the name
# breaking because  name !=  second
#
# 39:  The name of the name
# breaking because  name !=  second
#
# 40:  The name of the name
# breaking because  name !=  second
#
# 41:  The name of the name
# breaking because  name !=  second
#
# 42:  The name of the name
# breaking because  name !=  second
#
# 43:  The name of the name
# breaking because  name !=  second
#
# 44:  The name of the name
# breaking because  name !=  second
#
# 45:  The name of the name
# breaking because  name !=  second
#
# 46:  The name of the name
# breaking because  name !=  second
#
# 47:  The name of the name
# breaking because  name !=  second
#
# 48:  The name of the second,
# breaking because , !=  river
#
# 49:  The name of the second,
# breaking because , !=  river
#
# 50:  The name of the second,
# breaking because , !=  river
#
# 51:  The name of the second,
# breaking because , !=  river
#
# 52:  The name of the second,
# breaking because , !=  river
#
# 53:  The name of the second,
# breaking because , !=  river
#
# 54:  The name of the second,
# breaking because , !=  river
#
# 55:  The name of the second,
# breaking because , !=  river
#
# 56:  The name of the second,
# breaking because , !=  river
#
# 57:  The name of the second,
# breaking because , !=  river
#
# 58:  The name of the second,
# breaking because , !=  river
#
# 59:  The name of the name
# breaking because  name !=  second
#
# 60:  The name of the name
# breaking because  name !=  second
#
# 61:  The name of the second,
# breaking because , !=  river
#
# 62:  The name of the second,
# breaking because , !=  river
#
# 63:  The name of the second,
# breaking because , !=  river
#
# 64:  The name of the second second
# breaking because  second !=  river
#
# 65:  The name of the second name
# breaking because  name !=  river
#
# 66:  The name of the second name
# breaking because  name !=  river
#
# 67:  The name of the second name
# breaking because  name !=  river
#
# 68:  The name of the second river river
# breaking because  river !=  is
#
# 69:  The name of the second name
# breaking because  name !=  river
#
# 70:  The name of the second river river
# breaking because  river !=  is
#
# 71:  The of
# breaking because  of !=  name
#
# 72:  The name of the name
# breaking because  name !=  second
#
# 73:  The name of the name
# breaking because  name !=  second
#
# 74:  The name of the second name
# breaking because  name !=  river
#
# 75:  The name of the second name
# breaking because  name !=  river
#
# 76:  The name of the second name
# breaking because  name !=  river
#
# 77:  The name of the second river river
# breaking because  river !=  is
#
# 78:  The name of the second river of
# breaking because  of !=  is
#
# 79:  The name of the second river of
# breaking because  of !=  is
#
# 80:  The name of the second river is the
# breaking because  the !=  G
#
# 81:  The name of the name
# breaking because  name !=  second
#
# 82:  The name of the second name
# breaking because  name !=  river
#
# 83:  The name of the second river is the
# breaking because  the !=  G
#
# 84:  The name of the second river is the
# breaking because  the !=  G
#
# 85:  The name of the second river is the
# breaking because  the !=  G
#
# 86:  The name of the second river river
# breaking because  river !=  is
#
# 87:  The name of the second river is the
# breaking because  the !=  G
#
# 88:  The name of the name
# breaking because  name !=  second
#
# 89:  The name of the second river is the
# breaking because  the !=  G
#
# 90:  The name of the second river is the
# breaking because  the !=  G
#
# 91:  The name of the second river is the
# breaking because  the !=  G
#
# 92:  The name of the second river is the
# breaking because  the !=  G
#
# 93:  The river
# breaking because  river !=  name
#
# 94:  The name of the name
# breaking because  name !=  second
#
# 95:  The name of the second name
# breaking because  name !=  river
#
# 96:  The name of the second river of
# breaking because  of !=  is
#
# 97:  The name of the second river is the
# breaking because  the !=  G
#
# 98:  The name of the second river is the
# breaking because  the !=  G
#
# 99:  The name of the second river is the
# breaking because  the !=  G
#
#
# Working on verse [GEN 2:14_a][GEN 2:14_b] The name of the third river is Hiddekel; it runs along the east side of Assyria. And the fourth river is the Euphrates.
#
# 0: 's
# breaking because 's !=  The
#
# 1: 's
# breaking because 's !=  The
#
# 2:
#
# breaking because
#  !=  The
#
# 3:
#
# breaking because
#  !=  The
#
# 4:
#
# breaking because
#  !=  The
#
# 5:
#
# breaking because
#  !=  The
#
# 6:  The
#
# breaking because
#  !=  name
#
# 7:
#
# breaking because
#  !=  The
#
# 8:
#
# breaking because
#  !=  The
#
# 9:
#
# breaking because
#  !=  The
#
# 10:
#
# breaking because
#  !=  The
#
# 11:
#
# breaking because
#  !=  The
#
# 12:
#
# breaking because
#  !=  The
#
# 13:
#
# breaking because
#  !=  The
#
# 14:
#
# breaking because
#  !=  The
#
# 15:
#
# breaking because
#  !=  The
#
# 16:
#
# breaking because
#  !=  The
#
# 17:
#
# breaking because
#  !=  The
#
# 18:
#
# breaking because
#  !=  The
#
# 19:
#
# breaking because
#  !=  The
#
# 20:
#
# breaking because
#  !=  The
#
# 21:  The object
# breaking because  object !=  name
#
# 22:  The is
# breaking because  is !=  name
#
# 23:  The name of the person
# breaking because  person !=  third
#
# 24:  The name of the person
# breaking because  person !=  third
#
# 25:  The name of the person
# breaking because  person !=  third
#
# 26:  The name of the person
# breaking because  person !=  third
#
# 27:  The name of the person
# breaking because  person !=  third
#
# 28:  The name of the person
# breaking because  person !=  third
#
# 29:  The name of the person
# breaking because  person !=  third
#
# 30:  The name of the person
# breaking because  person !=  third
#
# 31:  The name of the third person
# breaking because  person !=  river
#
# 32:  The name of the person
# breaking because  person !=  third
#
# 33:  The name of the third person
# breaking because  person !=  river
#
# 34:  The name of the third degree
# breaking because  degree !=  river
#
# 35:  The name of the third degree
# breaking because  degree !=  river
#
# 36:  The name of the third-
# breaking because - !=  river
#
# 37:  The name of the third degree
# breaking because  degree !=  river
#
# 38:  The name of the third degree
# breaking because  degree !=  river
#
# 39:  The name of the third.
# breaking because . !=  river
#
# 40:  The name of the third country
# breaking because  country !=  river
#
# 41:  The name of the third.
# breaking because . !=  river
#
# 42:  The name of the third country
# breaking because  country !=  river
#
# 43:  The name of the third river,
# breaking because , !=  is
#
# 44:  The name of the third river,
# breaking because , !=  is
#
# 45:  The name of the third river,
# breaking because , !=  is
#
# 46:  The name of the third river,
# breaking because , !=  is
#
# 47:  The name of the third river,
# breaking because , !=  is
#
# 48:  The name of the third river,
# breaking because , !=  is
#
# 49:  The name of the third river is the
# breaking because  the !=  H
#
# 50:  The name of the third river,
# breaking because , !=  is
#
# 51:  The name of the third river is the
# breaking because  the !=  H
#
# 52:  The name of the third river is the
# breaking because  the !=  H
#
# 53:  The name of the third river is associated
# breaking because  associated !=  H
#
# 54:  The name of the third river is the
# breaking because  the !=  H
#
# 55:  The name of the third river is Humb
# breaking because umb != idd
#
# 56:  The name of the third river is Hiddud
# breaking because ud != e
#
# 57:  The name of the third river is Hidd.
# breaking because . != e
#
# 58:  The name of the third river is Hiddud
# breaking because ud != e
#
# 59:  The name of the third river is Hidd.
# breaking because . != e
#
# 60:  The name of the third river is Hidd.
# breaking because . != e
#
# 61:  The name of the third river is Hidd.
# breaking because . != e
#
# 62:  The name of the third river is Hidde.
# breaking because . != kel
#
# 63:  The name of the third river is Hidde.
# breaking because . != kel
#
# 64:  The name of the third river is Hidde.
# breaking because . != kel
#
# 65:  The name of the third river is Hiddeck
# breaking because ck != kel
#
# 66:  The name of the third river is Hidde.
# breaking because . != kel
#
# 67:  The name of the third river is Hiddekel.
# breaking because . != ;
#
# 68:  The name of the third river is Hiddekel.
# breaking because . != ;
#
# 69:  The name of the third river is Hiddekel.
# breaking because . != ;
#
# 70:  The name of the third river is Hiddekel; and
# breaking because  and !=  it
#
# 71:  The third
# breaking because  third !=  name
#
# 72:  The name the
# breaking because  the !=  of
#
# 73:  The name of the third river is Hidde (
# breaking because  ( != kel
#
# 74:  The name of the third party
# breaking because  party !=  river
#
# 75:  The name of the river
# breaking because  river !=  third
#
# 76:  The name of the third river is Hiddeld
# breaking because ld != kel
#
# 77:  The name of the third river is Hiddekel.
# breaking because . != ;
#
# 78:  The name of the third river is Hiddekel; and
# breaking because  and !=  it
#
# 79:  The name of the third river is Hiddekel; it is
# breaking because  is !=  runs
#
# 80:  The name of the third river is Hiddekel; it is
# breaking because  is !=  runs
#
# 81:  The name of the third river is Hiddekel; and
# breaking because  and !=  it
#
# 82:  The name of the third river is Hiddekel; it is
# breaking because  is !=  runs
#
# 83:  The name of the third river is Hiddekel; it runs next
# breaking because  next !=  along
#
# 84:  The name of the third river is Hiddekel; it runs in
# breaking because  in !=  along
#
# 85:  The name of the third river is Hiddekel; it runs in
# breaking because  in !=  along
#
# 86:  The name of the third river is Hiddekel; it runs in
# breaking because  in !=  along
#
# 87:  The name of the third river is Hiddekel; it runs along the Tig
# breaking because  Tig !=  east
#
# 88:  The name of the third party
# breaking because  party !=  river
#
# 89:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 90:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 91:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 92:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 93:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 94:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 95:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 96:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 97:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 98:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
# 99:  The name of the third river is Hiddekel; it runs along the banks
# breaking because  banks !=  east
#
#
# Working on verse [GEN 2:15_a][GEN 2:15_b] Then the LORD God took the man and placed him in the Garden of Eden to cultivate and keep it.
#
# 0:
#
# breaking because
#  !=  Then
#
# 1:
#
# breaking because
#  !=  Then
#
# 2:
#
# breaking because
#  !=  Then
#
# 3:
#
# breaking because
#  !=  Then
#
# 4:
#
# breaking because
#  !=  Then
#
# 5:  Then The
# breaking because  The !=  the
#
# 6:  Then You
# breaking because  You !=  the
#
# 7:  Then,
# breaking because , !=  the
#
# 8:  Then-
# breaking because - !=  the
#
# 9:  Then the-
# breaking because - !=  LORD
#
# 10:  Then the-
# breaking because - !=  LORD
#
# 11:  Then the-
# breaking because - !=  LORD
#
# 12:  Then the-
# breaking because - !=  LORD
#
# 13:  Then the New
# breaking because  New !=  LORD
#
# 14:  Then the New
# breaking because  New !=  LORD
#
# 15:  Then the New
# breaking because  New !=  LORD
#
# 16:  Then the-
# breaking because - !=  LORD
#
# 17:  Then the New
# breaking because  New !=  LORD
#
# 18:  Then the LORD'
# breaking because ' !=  God
#
# 19:  Then the Lord
# breaking because  Lord !=  LORD
#
# 20:  Then the LORD God is
# breaking because  is !=  took
#
# 21:  Then the LORD God is
# breaking because  is !=  took
#
# 22:  Then the LORD God is
# breaking because  is !=  took
#
# 23:  Then the LORD God is
# breaking because  is !=  took
#
# 24:  Then the LORD God is
# breaking because  is !=  took
#
# 25:  Then the LORD God is
# breaking because  is !=  took
#
# 26:  Then the LORD God is
# breaking because  is !=  took
#
# 27:  Then the LORD God took its
# breaking because  its !=  the
#
# 28:  Then the LORD God took the bread
# breaking because  bread !=  man
#
# 29:  Then the LORD God took the bread
# breaking because  bread !=  man
#
# 30:  Then the LORD God took the...
# breaking because ... !=  man
#
# 31:  Then the LORD God took the...
# breaking because ... !=  man
#
# 32:  Then the LORD God took the...
# breaking because ... !=  man
#
# 33:  Then the LORD God took the man.
# breaking because . !=  and
#
# 34:  Then the LORD God took the man.
# breaking because . !=  and
#
# 35:  Then the LORD God took the man.
# breaking because . !=  and
#
# 36:  Then the LORD God took the man.
# breaking because . !=  and
#
# 37:  Then the LORD God took the man and his
# breaking because  his !=  placed
#
# 38:  Then the LORD God took the man and took
# breaking because  took !=  placed
#
# 39:  Then the LORD God took its
# breaking because  its !=  the
#
# 40:  Then the LORD God took the man and his
# breaking because  his !=  placed
#
# 41:  Then the LORD God took the man and placed him on
# breaking because  on !=  in
#
# 42:  Then the LORD God took the man and placed him in the squad
# breaking because  squad !=  Garden
#
# 43:  Then the LORD God took the man and placed him in the "
# breaking because  " !=  Garden
#
# 44:  Then the LORD God took the man and his
# breaking because  his !=  placed
#
# 45:  Then the LORD God took the man and placed him in the womb
# breaking because  womb !=  Garden
#
# 46:  Then Jesus
# breaking because  Jesus !=  the
#
# 47:  Then the LORD God took its
# breaking because  its !=  the
#
# 48:  Then the LORD God took the man and placed him in the m
# breaking because  m !=  Garden
#
# 49:  Then the LORD God took the man and placed him in the world
# breaking because  world !=  Garden
#
# 50:  Then the LORD God took the man and placed him in the Garden of G
# breaking because  G !=  Eden
#
# 51:  Then the LORD God took the man and placed him in the Garden of Eden.
# breaking because . !=  to
#
# 52:  Then the LORD God took the man and placed him in the Garden of Eden.
# breaking because . !=  to
#
# 53:  Then the LORD God took the man and placed him in the Garden of Eden to be
# breaking because  be !=  cultivate
#
# 54:  Then the LORD God took the man and placed him in the Garden of Eden to be
# breaking because  be !=  cultivate
#
# 55:  Then the LORD God took the man and placed him in the Garden of Eden to be
# breaking because  be !=  cultivate
#
# 56:  Then the LORD God took the man and placed him in the Garden of Eden to make
# breaking because  make !=  cultivate
#
# 57:  Then the LORD God took the town
# breaking because  town !=  man
#
# 58:  Then the LORD Godly
# breaking because ly !=  took
#
# 59:  Then the LORD God took the man and placed him in the Garden of Eden.
# breaking because . !=  to
#
# 60:  Then the LORD God took the man and placed him in the Garden of Eden.
# breaking because . !=  to
#
# 61:  Then the LORD took
# breaking because  took !=  God
#
# 62:  Then the LORD God took the man and placed him in the ground
# breaking because  ground !=  Garden
#
# 63:  Then the LORD God took the man and placed him in the Garden of Eden to make
# breaking because  make !=  cultivate
#
# 64:  Then the LORD God took the man and placed him in the Garden of Eden to be
# breaking because  be !=  cultivate
#
# 65:  Then the LORD God took the man and placed him in the Garden of Eden to make
# breaking because  make !=  cultivate
#
# 66:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and raise
# breaking because  raise !=  keep
#
# 67:  Then the LORD Godly
# breaking because ly !=  took
#
# 68:  Then the LORD God took the man and placed him in the Garden of Eden.
# breaking because . !=  to
#
# 69:  Then the LORD God took the man and placed him in the Garden of Eden to make
# breaking because  make !=  cultivate
#
# 70:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and nurture
# breaking because  nurture !=  keep
#
# 71:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and raise
# breaking because  raise !=  keep
#
# 72:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and nurture
# breaking because  nurture !=  keep
#
# 73:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and keep his
# breaking because  his !=  it
#
# 74:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and keep them
# breaking because  them !=  it
#
# 75:
#
# breaking because
#  !=  Then
#
# 76:  Then the LORD God will
# breaking because  will !=  took
#
# 77:  Then the LORD were
# breaking because  were !=  God
#
# 78:  Then the LORD God took the man and placed him in the Garden of Eden to make
# breaking because  make !=  cultivate
#
# 79:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and flourish
# breaking because  flourish !=  keep
#
# 80:  Then the LORD God took the man and placed him in the Garden of Eden to make
# breaking because  make !=  cultivate
#
# 81:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and respect
# breaking because  respect !=  keep
#
# 82:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and keep his
# breaking because  his !=  it
#
# 83:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and keep it Temple
# breaking because  Temple != .
#
# 84:  Then the LORD God took the man and placed him in the Garden of Eden to cultivate and keep it.
#
# Working on verse [GEN 2:16_a][GEN 2:16_b] And the LORD God commanded him, “You may eat freely from every tree of the garden,
#
# 0: .
# breaking because . !=  And
#
# 1: .
# breaking because . !=  And
#
# 2: .
# breaking because . !=  And
#
# 3: ,
# breaking because , !=  And
#
# 4: ,
# breaking because , !=  And
#
# 5: ,
# breaking because , !=  And
#
# 6:  And The
# breaking because  The !=  the
#
# 7:  And the people
# breaking because  people !=  LORD
#
# 8:  And the great
# breaking because  great !=  LORD
#
# 9:  And the Lord
# breaking because  Lord !=  LORD
#
# 10:  And the Lord
# breaking because  Lord !=  LORD
#
# 11:  And the Lord
# breaking because  Lord !=  LORD
#
# 12:  And the LORD said
# breaking because  said !=  God
#
# 13:  And the LORD said
# breaking because  said !=  God
#
# 14:  And the and
# breaking because  and !=  LORD
#
# 15:  And I
# breaking because  I !=  the
#
# 16:  And I
# breaking because  I !=  the
#
# 17:  And I
# breaking because  I !=  the
#
# 18:  And the first
# breaking because  first !=  LORD
#
# 19:  And the first
# breaking because  first !=  LORD
#
# 20:  And the first
# breaking because  first !=  LORD
#
# 21:  And the man
# breaking because  man !=  LORD
#
# 22:  And the man
# breaking because  man !=  LORD
#
# 23:  And the man
# breaking because  man !=  LORD
#
# 24:  And the man
# breaking because  man !=  LORD
#
# 25:  And the LORD,
# breaking because , !=  God
#
# 26:  And the LORD,
# breaking because , !=  God
#
# 27:  And the LORD of
# breaking because  of !=  God
#
# 28:  And the LORD of
# breaking because  of !=  God
#
# 29:  And the LORD God,
# breaking because , !=  commanded
#
# 30:  And the LORD God said
# breaking because  said !=  commanded
#
# 31:  And the LORD God said
# breaking because  said !=  commanded
#
# 32:  And the LORD God said
# breaking because  said !=  commanded
#
# 33:  And the LORD God said
# breaking because  said !=  commanded
#
# 34:  And the LORD God commanded the
# breaking because  the !=  him
#
# 35:  And the LORD God commanded the
# breaking because  the !=  him
#
# 36:  And the LORD God commanded them
# breaking because  them !=  him
#
# 37:  And the LORD God commanded him, and
# breaking because  and !=  �
#
# 38:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 39:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 40:  And the LORD God commanded us
# breaking because  us !=  him
#
# 41:  And the LORD God said
# breaking because  said !=  commanded
#
# 42:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 43:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 44:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 45:  And the LORD God commanded him, ��
# breaking because � != �
#
# 46:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 47:  �
# breaking because  � !=  And
#
# 48:  And the LORD God commanded him, ��
# breaking because � != �
#
# 49:  And the LORD God commanded him, � �
# breaking because  � != �
#
# 50:  And the LORD God,
# breaking because , !=  commanded
#
# 51:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 52:  And the LORD God commanded him, ��
# breaking because � != �
#
# 53:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 54:  And the LORD God commanded him, ���
# breaking because � != You
#
# 55:  And the LORD God commanded him, ���
# breaking because � != You
#
# 56:  And the LORD God commanded him, ���
# breaking because � != You
#
# 57:  And the LORD God commanded him, Go
# breaking because  Go !=  �
#
# 58:  And the LORD God commanded him, ���
# breaking because � != You
#
# 59:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 60:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 61:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 62:  And the LORD God commanded him, ��You have
# breaking because  have !=  may
#
# 63:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 64:  And the LORD God commanded him, ��You �
# breaking because  � !=  may
#
# 65:  And the LORD God made
# breaking because  made !=  commanded
#
# 66:  And the LORD God made
# breaking because  made !=  commanded
#
# 67:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 68:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 69:  And theant
# breaking because ant !=  LORD
#
# 70:  And the LORD GOD
# breaking because  GOD !=  God
#
# 71:  And the LORD GOD
# breaking because  GOD !=  God
#
# 72:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 73:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 74:  And the LORD God commanded him, �� �
# breaking because  � != You
#
# 75:  And the LORD God commanded him, ��You shalt
# breaking because  shalt !=  may
#
# 76:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 77:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 78:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 79:  And the LORD God commanded him, ��You may not
# breaking because  not !=  eat
#
# 80:  And the LORD God commanded him, ��You may not
# breaking because  not !=  eat
#
# 81:  And the LORD God commanded him, ��You may not
# breaking because  not !=  eat
#
# 82:  And the LORD God commanded him, "
# breaking because  " !=  �
#
# 83:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 84:  And the LORD God commanded him, ��You may not
# breaking because  not !=  eat
#
# 85:  And the LORD God commanded him, ��You may not
# breaking because  not !=  eat
#
# 86:  And the LORD God commanded him, ��You may take
# breaking because  take !=  eat
#
# 87:  And the LORD God commanded him, ��You may take
# breaking because  take !=  eat
#
# 88:  And the LORD God commanded him, ��You may take
# breaking because  take !=  eat
#
# 89:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 90:  And the LORD God commanded him, ��You may take
# breaking because  take !=  eat
#
# 91:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 92:  And the LORD God commanded him, ��You may eat it
# breaking because  it !=  freely
#
# 93:  And the LORD God commanded him, ��You shall
# breaking because  shall !=  may
#
# 94:  And the LORD God commanded him, ��You may eat and
# breaking because  and !=  freely
#
# 95:  And the LORD God commanded him, ��You may eat and
# breaking because  and !=  freely
#
# 96:  And the LORD God commanded him, ��You may eat it
# breaking because  it !=  freely
#
# 97:  And the LORD God commanded him, ��You may eat it
# breaking because  it !=  freely
#
# 98:  And the LORD God commanded you
# breaking because  you !=  him
#
# 99:  And the LORD God commanded him, "
# breaking because  " !=  �
#
#
# Working on verse [GEN 2:17_a][GEN 2:17_b] but you must not eat from the tree of the knowledge of good and evil; for in the day that you eat of it, you will surely die.”
#
# 0: /
# breaking because / !=  but
#
# 1: .
# breaking because . !=  but
#
# 2: ,
# breaking because , !=  but
#
# 3: ,
# breaking because , !=  but
#
# 4: ,
# breaking because , !=  but
#
# 5:  and
# breaking because  and !=  but
#
# 6:  and
# breaking because  and !=  but
#
# 7:  but
#
# breaking because
#  !=  you
#
# 8:  but you you
# breaking because  you !=  must
#
# 9:  but the
# breaking because  the !=  you
#
# 10:  but you you
# breaking because  you !=  must
#
# 11:  but you.
# breaking because . !=  must
#
# 12:  but as
# breaking because  as !=  you
#
# 13:  but you you
# breaking because  you !=  must
#
# 14:  but Choose
# breaking because  Choose !=  you
#
# 15:  but you must give
# breaking because  give !=  not
#
# 16:  but you must not be
# breaking because  be !=  eat
#
# 17:  but they
# breaking because  they !=  you
#
# 18:  but you can
# breaking because  can !=  must
#
# 19:  but you must not be
# breaking because  be !=  eat
#
# 20:  but you must not be
# breaking because  be !=  eat
#
# 21:  but you must not be
# breaking because  be !=  eat
#
# 22:  but you must not be
# breaking because  be !=  eat
#
# 23:  but you must not be
# breaking because  be !=  eat
#
# 24:  but you must not be
# breaking because  be !=  eat
#
# 25:  but you must not be
# breaking because  be !=  eat
#
# 26:  but you must not eat.
# breaking because . !=  from
#
# 27:  but you must not eat from it
# breaking because  it !=  the
#
# 28:  but you must not be
# breaking because  be !=  eat
#
# 29:  but you must not eat from the same
# breaking because  same !=  tree
#
# 30:  but you must not eat from it
# breaking because  it !=  the
#
# 31:  but you are
# breaking because  are !=  must
#
# 32:  but you must not be
# breaking because  be !=  eat
#
# 33:  but you must not eat from the same
# breaking because  same !=  tree
#
# 34:  but you must not eat from the tree of life
# breaking because  life !=  the
#
# 35:  but you must not eat from the tree of the tree
# breaking because  tree !=  knowledge
#
# 36:  but you have
# breaking because  have !=  must
#
# 37:  but you must not be
# breaking because  be !=  eat
#
# 38:  but you must not eat from the tree of the but
# breaking because  but !=  knowledge
#
# 39:  but you be
# breaking because  be !=  must
#
# 40:  but you must not eat from it
# breaking because  it !=  the
#
# 41:  but you must not eat from the tree of knowledge
# breaking because  knowledge !=  the
#
# 42:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 43:  but you must not eat from the tree of knowledge
# breaking because  knowledge !=  the
#
# 44:  but you must not eat from the tree of the tree
# breaking because  tree !=  knowledge
#
# 45:  but you must not eat from the tree of life
# breaking because  life !=  the
#
# 46:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 47:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 48:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 49:  but you must not eat from the tree of the knowledge of good and from
# breaking because  from !=  evil
#
# 50:  but you must not eat from the tree of the knowledge of good and evil.
# breaking because . != ;
#
# 51:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 52:  but you must not eat from the tree of the knowledge of good and evil.
# breaking because . != ;
#
# 53:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 54:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 55:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 56:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 57:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 58:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 59:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 60:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 61:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 62:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 63:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 64:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 65:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 66:  but you must not eat from the tree of knowledge
# breaking because  knowledge !=  the
#
# 67:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 68:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 69:  but you must not eat from the tree of the knowledge of good and evil,
# breaking because , != ;
#
# 70:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 71:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 72:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 73:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 74:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 75:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 76:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 77:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 78:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 79:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 80:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 81:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 82:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 83:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 84:  but you must not eat from the tree of the knowledge of good and evil; for in the beginning
# breaking because  beginning !=  day
#
# 85:  but you must not eat from the tree of the knowledge of good and evil; for in the day of
# breaking because  of !=  that
#
# 86:  but a
# breaking because  a !=  you
#
# 87:  but you must not eat from the tree of knowledge
# breaking because  knowledge !=  the
#
# 88:  but you you
# breaking because  you !=  must
#
# 89:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 90:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 91:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 92:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 93:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 94:  but you must not eat from the tree of the knowledge of good and evil; for in the beginning
# breaking because  beginning !=  day
#
# 95:  but you must not eat from the tree of the knowledge of good and evil; for in the day of
# breaking because  of !=  that
#
# 96:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
# 97:  but you must not eat from the tree of the knowledge of good and evil; for in the day that you are
# breaking because  are !=  eat
#
# 98:  but you must not eat from the tree of the knowledge of the
# breaking because  the !=  good
#
# 99:  but you must not eat from the tree of the knowledge of good and evil; for the
# breaking because  the !=  in
#
#
# Working on verse [GEN 2:18_a][GEN 2:18_b] The LORD God also said, “It is not good for the man to be alone. I will make for him a suitable helper.”
#
# 0:
#
# breaking because
#  !=  The
#
# 1:
#
# breaking because
#  !=  The
#
# 2:
#
# breaking because
#  !=  The
#
# 3:
#
# breaking because
#  !=  The
#
# 4:
#
# breaking because
#  !=  The
#
# 5:
#
# breaking because
#  !=  The
#
# 6:
#
# breaking because
#  !=  The
#
# 7:
#
# breaking because
#  !=  The
#
# 8:
#
# breaking because
#  !=  The
#
# 9:  The "
# breaking because  " !=  LORD
#
# 10:  Theis
# breaking because is !=  LORD
#
# 11:  The New
# breaking because  New !=  LORD
#
# 12:  The "
# breaking because  " !=  LORD
#
# 13:  The first
# breaking because  first !=  LORD
#
# 14:  The Book
# breaking because  Book !=  LORD
#
# 15:  The
#
# breaking because
#  !=  LORD
#
# 16:  The Book
# breaking because  Book !=  LORD
#
# 17:  The
#
# breaking because
#  !=  LORD
#
# 18:  The Lord
# breaking because  Lord !=  LORD
#
# 19:  The
#
# breaking because
#  !=  LORD
#
# 20:  The Great
# 79:  The LORD God also also
# breaking because  also !=  said
#
# 80:  The LORD God also said,,
# breaking because , !=  �
#
# 81:  The LORD God also said,,
# breaking because , !=  �
#
# 82:  The LORD God also said,,
# breaking because , !=  �
#
# 83:  The LORD God also said, � �
# breaking because  � != �
#
# 84:  The LORD God God
# breaking because  God !=  also
#
# 85:  The LORD God also also
# breaking because  also !=  said
#
# 86:  The LORD God also said said
# breaking because  said != ,
#
# 87:  The LORD God also said,,
# breaking because , !=  �
#
# 88:  The LORD God also said,,
# breaking because , !=  �
#
# 89:  The LORD God God
# breaking because  God !=  also
#
# 90:  LORD
# breaking because  LORD !=  The
#
# 91:  The LORD God also said all
# breaking because  all != ,
#
# 92:  The LORD God also said,,
# breaking because , !=  �
#
# 93:  The LORD God God
# breaking because  God !=  also
#
# 94:  The LORD God also said,,
# breaking because , !=  �
#
# 95:  The LORD God also said �
# breaking because  � != ,
#
# 96:  The LORD God also said,,
# breaking because , !=  �
#
# 97:  The LORD God also said, � �
# breaking because  � != �
#
# 98:  The LORD God said
# breaking because  said !=  also
#
# 99:  The LORD God also also
# breaking because  also !=  said
#
#
# Working on verse [GEN 2:19_a][GEN 2:19_b] And out of the ground the LORD God formed every beast of the field and every bird of the air, and He brought them to the man to see what he would name each one. And whatever the man called each living creature, that was its name.
#
# 0: ,
# breaking because , !=  And
#
# 1:
#
# breaking because
#  !=  And
#
# 2:
#
# breaking because
#  !=  And
#
# 3:
#
# breaking because
#  !=  And
#
# 4:  And The
# breaking because  The !=  out
#
# 5:
#
# breaking because
#  !=  And
#
# 6:
#
# breaking because
#  !=  And
#
# 7:  And the
# breaking because  the !=  out
#
# 8:  And the
# breaking because  the !=  out
#
# 9:  And the
# breaking because  the !=  out
#
# 10:  And the
# breaking because  the !=  out
#
# 11:  And the
# breaking because  the !=  out
#
# 12:  And the
# breaking because  the !=  out
#
# 13:  And the
# breaking because  the !=  out
#
# 14:  And that
# breaking because  that !=  out
#
# 15:  And that
# breaking because  that !=  out
#
# 16:  And the
# breaking because  the !=  out
#
# 17:  And the
# breaking because  the !=  out
#
# 18:  And the
# breaking because  the !=  out
#
# 19:  And and
# breaking because  and !=  out
#
# 20:  And out out
# breaking because  out !=  of
#
# 21:  And with
# breaking because  with !=  out
#
# 22:  And out out
# breaking because  out !=  of
#
# 23:  And with
# breaking because  with !=  out
#
# 24:  And out of out
# breaking because  out !=  the
#
# 25:  And out of the world
# breaking because  world !=  ground
#
# 26:  And out of the world
# breaking because  world !=  ground
#
# 27:  And out of the ground.
# breaking because . !=  the
#
# 28:  And out of the back
# breaking because  back !=  ground
#
# 29:  And the
# breaking because  the !=  out
#
# 30:  And out of the ground.
# breaking because . !=  the
#
# 31:  And out of the ground.
# breaking because . !=  the
#
# 32:  And out of the ground.
# breaking because . !=  the
#
# 33:  And in
# breaking because  in !=  out
#
# 34:  And out of the ground,
# breaking because , !=  the
#
# 35:  And out of the ground,
# breaking because , !=  the
#
# 36:  And out of the ground,
# breaking because , !=  the
#
# 37:  And out of the ground,
# breaking because , !=  the
#
# 38:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 39:  And out of the ground,
# breaking because , !=  the
#
# 40:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 41:  And out of the ground,
# breaking because , !=  the
#
# 42:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 43:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 44:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 45:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 46:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 47:  And out of the country
# breaking because  country !=  ground
#
# 48:  And out of the ground,
# breaking because , !=  the
#
# 49:  And out of the ground,
# breaking because , !=  the
#
# 50:  And out of the ground the earth
# breaking because  earth !=  LORD
#
# 51:  And out of the earth
# breaking because  earth !=  ground
#
# 52:  And Of
# breaking because  Of !=  out
#
# 53:  And out of the ground.
# breaking because . !=  the
#
# 54:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 55:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 56:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 57:  And out of the Gates
# breaking because  Gates !=  ground
#
# 58:  And out of the earth
# breaking because  earth !=  ground
#
# 59:  And out of the ground the earth
# breaking because  earth !=  LORD
#
# 60:  And out of the ground the LORD said
# breaking because  said !=  God
#
# 61:  And out of the ground the LORD said
# breaking because  said !=  God
#
# 62:  And out of the ground the LORD your
# breaking because  your !=  God
#
# 63:  And out of the ground the LORD God said
# breaking because  said !=  formed
#
# 64:  And out of the ground,
# breaking because , !=  the
#
# 65:  And out of the ground the game
# breaking because  game !=  LORD
#
# 66:  And out of the ground the LORD's
# breaking because 's !=  God
#
# 67:  And out of the ground the LORD God said
# breaking because  said !=  formed
#
# 68:  And out of the ground the LORD God revealed
# breaking because  revealed !=  formed
#
# 69:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 70:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 71:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 72:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 73:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 74:  And out of the ground,
# breaking because , !=  the
#
# 75:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 76:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 77:  And out of the ground the LORD God formed a
# breaking because  a !=  every
#
# 78:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 79:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 80:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 81:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 82:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 83:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 84:  And out of the ground the ground
# breaking because  ground !=  LORD
#
# 85:  And of
# breaking because  of !=  out
#
# 86:  And out of the earth
# breaking because  earth !=  ground
#
# 87:  And out of the ground the LORD God made
# breaking because  made !=  formed
#
# 88:  And out of the ground the LORD God created
# breaking because  created !=  formed
#
# 89:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 90:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 91:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 92:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 93:  And out of the ground the LORD God formed every part
# breaking because  part !=  beast
#
# 94:  And out of the ground there
# breaking because  there !=  the
#
# 95:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 96:  And out of the ground the LORD God formed every part
# breaking because  part !=  beast
#
# 97:  And out of the ground the LORD God formed the
# breaking because  the !=  every
#
# 98:  And out of the ground the LORD God formed every beast and
# breaking because  and !=  of
#
# 99:  And out of the ground of
# breaking because  of !=  the
#
#
# Working on verse [GEN 2:20_a][GEN 2:20_b] The man gave names to all the livestock, to the birds of the air, and to every beast of the field. But for Adam no suitable helper was found.
#
# 0:  is
# breaking because  is !=  The
#
# 1:
#
# breaking because
#  !=  The
#
# 2:
#
# breaking because
#  !=  The
#
# 3:
#
# breaking because
#  !=  The
#
# 4:
#
# breaking because
#  !=  The
#
# 5:  The,
# breaking because , !=  man
#
# 6:  The,
# breaking because , !=  man
#
# 7:  The,
# breaking because , !=  man
#
# 8:  The,
# breaking because , !=  man
#
# 9:  The,
# breaking because , !=  man
#
# 10:  The,
# breaking because , !=  man
#
# 11:  The,
# breaking because , !=  man
#
# 12:  The,
# breaking because , !=  man
#
# 13:  The,
# breaking because , !=  man
#
# 14:  The,
# breaking because , !=  man
#
# 15:  The,
# breaking because , !=  man
#
# 16:  The,
# breaking because , !=  man
#
# 17:  The,
# breaking because , !=  man
#
# 18:  The,
# breaking because , !=  man
#
# 19:  The,
# breaking because , !=  man
#
# 20:  The,
# breaking because , !=  man
#
# 21:  The,
# breaking because , !=  man
#
# 22:  The,
# breaking because , !=  man
#
# 23:  The,
# breaking because , !=  man
#
# 24:  The,
# breaking because , !=  man
#
# 25:  The,
# breaking because , !=  man
#
# 26:  The,
# breaking because , !=  man
#
# 27:  The,
# breaking because , !=  man
#
# 28:  The man,
# breaking because , !=  gave
#
# 29:  The man,
# breaking because , !=  gave
#
# 30:  The man,
# breaking because , !=  gave
#
# 31:  The man,
# breaking because , !=  gave
#
# 32:  The man,
# breaking because , !=  gave
#
# 33:  The man,
# breaking because , !=  gave
#
# 34:  The man,
# breaking because , !=  gave
#
# 35:  The man,
# breaking because , !=  gave
#
# 36:  The the
# breaking because  the !=  man
#
# ...
#
# 34:  The Nephilim were the
# breaking because  the !=  on
#
# 35:  The Nephilim were in
# breaking because  in !=  on
#
# 36:  The Nephilim were in
# breaking because  in !=  on
#
# 37:  The Nephilim were in
# breaking because  in !=  on
#
# 38:  The Nephilim were in
# breaking because  in !=  on
#
# 39:  The Nephilim were in
# breaking because  in !=  on
#
# 40:  The Nephilim were in
# breaking because  in !=  on
#
# 41:  The Nephilim were in
# breaking because  in !=  on
#
# 42:  The Nephilim were in
# breaking because  in !=  on
#
# 43:  The Nephilim were in
# breaking because  in !=  on
#
# 44:  The Nephilim were in
# breaking because  in !=  on
#
# 45:  The Nephilim were in
# breaking because  in !=  on
#
# 46:  The Nephilim were in
# breaking because  in !=  on
#
# 47:  The Nephilim were in
# breaking because  in !=  on
#
# 48:  The Nephilim were in
# breaking because  in !=  on
#
# 49:  The Nephilim were in
# breaking because  in !=  on
#
# 50:  The Nephilim were in
# breaking because  in !=  on
#
# 51:  The Nephilim were in
# breaking because  in !=  on
#
# 52:  The Nephilim were on the surface
# breaking because  surface !=  earth
#
# 53:  The Nephilim were on the on
# breaking because  on !=  earth
#
# 54:  Neph
# breaking because  Neph !=  The
#
# 55:  The Dawn
# breaking because  Dawn !=  Neph
#
# 56:  Neph
# breaking because  Neph !=  The
#
# 57:  The Nephil's
# breaking because 's != im
#
# 58:  The Nephilim Nec
# breaking because  Nec !=  were
#
# 59:  The Nephilim were in
# breaking because  in !=  on
#
# 60:  The Nephilim were in
# breaking because  in !=  on
#
# 61:  The Nephilim were in
# breaking because  in !=  on
#
# 62:  The Nephilim were in
# breaking because  in !=  on
#
# 63:  The Nephilim were in
# breaking because  in !=  on
#
# 64:  The Nephilim were on the planet
# breaking because  planet !=  earth
#
# 65:  The Nephilim were on the planet
# breaking because  planet !=  earth
#
# 66:  The Nephilim were on the planet
# breaking because  planet !=  earth
#
# 67:  The Nephilim were on the planet
# breaking because  planet !=  earth
#
# 68:  The Nephilim were on the planet
# breaking because  planet !=  earth
#
# 69:  The Nephilim were on the planet
# breaking because  planet !=  earth
#
# 70:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 71:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 72:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 73:  The Nephilim were on the earth)
# breaking because ) !=  in
#
# 74:  The Nephilim were on the earth)
# breaking because ) !=  in
#
# 75:  The Nephilim were on the earth)
# breaking because ) !=  in
#
# 76:  The Nephilim were on the earth)
# breaking because ) !=  in
#
# 77:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 78:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 79:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 80:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 81:  The Nephilim were in
# breaking because  in !=  on
#
# 82:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 83:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 84:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 85:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 86:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 87:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 88:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 89:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 90:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 91:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 92:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 93:  The Nephites
# breaking because ites != il
#
# 94:  The Nephilons
# breaking because ons != im
#
# 95:  The Nephilim were in
# breaking because  in !=  on
#
# 96:  The Nephilim were on the earth in the
# breaking because  the !=  those
#
# 97:  The Nephilim were on the earth,
# breaking because , !=  in
#
# 98:  The Nephilim were Neph
# breaking because  Neph !=  on
#
# 99:  The were
# breaking because  were !=  Neph
#
#
# Working on verse [GEN 6:5_a][GEN 6:5_b] Then the LORD saw that the wickedness of man was great upon the earth, and that every inclination of the thoughts of his heart was altogether evil all the time.
#
# 0: .
# breaking because . !=  Then
#
# 1:
#
# breaking because
#  !=  Then
#
# 2:
#
# breaking because
#  !=  Then
#
# 3:
#
# breaking because
#  !=  Then
#
# 4:
#
# breaking because
#  !=  Then
#
# 5:
#
# breaking because
#  !=  Then
#
# 6:
#
# breaking because
#  !=  Then
#
# 7:
#
# breaking because
#  !=  Then
#
# 8:  Then,
# breaking because , !=  the
#
# 9:  "
# breaking because  " !=  Then
#
# 10:  Then The
# breaking because  The !=  the
#
# 11:  Then a
# breaking because  a !=  the
#
# 12:  Then the the
# breaking because  the !=  LORD
#
# 13:  Then the "
# breaking because  " !=  LORD
#
# 14:  Then the "
# breaking because  " !=  LORD
#
# 15:  Then the "
# breaking because  " !=  LORD
#
# 16:  Then the "
# breaking because  " !=  LORD
#
# 17:  Then the "
# breaking because  " !=  LORD
#
# 18:  Then the "
# breaking because  " !=  LORD
#
# 19:  Then the Lord
# breaking because  Lord !=  LORD
#
# 20:  Then the Lord
# breaking because  Lord !=  LORD
#
# 21:  Then the Lord
# breaking because  Lord !=  LORD
#
# 22:  Then the LORD said
# breaking because  said !=  saw
#
# 23:  Then the LORD said
# breaking because  said !=  saw
#
# 24:  Then the Lord
# breaking because  Lord !=  LORD
#
# 25:  Then the LORD said
# breaking because  said !=  saw
#
# 26:  Then the LORD answered
# breaking because  answered !=  saw
#
# 27:  Then the LORD said
# breaking because  said !=  saw
#
# 28:  Then the LORD answered
# breaking because  answered !=  saw
#
# 29:  Then the LORD answered
# breaking because  answered !=  saw
#
# 30:  Then the LORD answered
# breaking because  answered !=  saw
#
# 31:  Then the LORD saw,
# breaking because , !=  that
#
# 32:  Then the LORD saw the
# breaking because  the !=  that
#
# 33:  Then the Lord
# breaking because  Lord !=  LORD
#
# 34:  Then the LORD saw,
# breaking because , !=  that
#
# 35:  Then the LORD saw the
# breaking because  the !=  that
#
# 36:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 37:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 38:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 39:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 40:  Then the LORD saw that the people
# breaking because  people !=  wicked
#
# 41:  Then the ref
# breaking because  ref !=  LORD
#
# 42:  Then they
# breaking because  they !=  the
#
# 43:  Then the Century
# breaking because  Century !=  LORD
#
# 44:  Then they
# breaking because  they !=  the
#
# 45:  Then they
# breaking because  they !=  the
#
# 46:  Then the Lord
# breaking because  Lord !=  LORD
#
# 47:  Then the LORD said
# breaking because  said !=  saw
#
# 48:  Then the LORD the
# breaking because  the !=  saw
#
# 49:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 50:  Then the LORD saw,
# breaking because , !=  that
#
# 51:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 52:  Then the LORD saw that the wicked and
# breaking because  and != ness
#
# 53:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 54:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 55:  Then the LORD saw that the LORD
# breaking because  LORD !=  wicked
#
# 56:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 57:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 58:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 59:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 60:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 61:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 62:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 63:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 64:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 65:  Then the LORD saw that the wickedness of man was not
# breaking because  not !=  great
#
# 66:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 67:  Then the LORD saw that the wickedness of man was greater
# breaking because  greater !=  great
#
# 68:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 69:  Then they
# breaking because  they !=  the
#
# 70:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 71:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 72:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 73:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 74:  Then the LORD saw that the wickedness of man was great.
# breaking because . !=  upon
#
# 75:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 76:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 77:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 78:  Then the LORD saw that he
# breaking because  he !=  the
#
# 79:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 80:  Then the LORD saw that the wickedness of man was greatly
# breaking because  greatly !=  great
#
# 81:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 82:  Then the LORD saw that the wickedness of man was great in
# breaking because  in !=  upon
#
# 83:  Then the LORD saw that the wickedness of man was great upon them
# breaking because  them !=  the
#
# 84:  Then the LORD EV
# breaking because  EV !=  saw
#
# 85:  Then he
# breaking because  he !=  the
#
# 86:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 87:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 88:  Then the LORD saw that the wickedness of man was great in
# breaking because  in !=  upon
#
# 89:  Then the LORD saw that the wickedness of man was great upon the wicked
# breaking because  wicked !=  earth
#
# 90:  Then the LORD saw that the wicked man
# breaking because  man != ness
#
# 91:  Then the LORD saw that the wickedness of the
# breaking because  the !=  man
#
# 92:  Then the LORD saw that the wickedness of man was great and
# breaking because  and !=  upon
#
# 93:  Then the LORD saw that the wickedness of man was great upon them
# breaking because  them !=  the
#
# 94:  Then the LORD saw that the wickedness of man was great upon the face
# breaking because  face !=  earth
#
# 95:  Then the LORD saw that the wickedness of man was great upon the earth:
# breaking because : != ,
#
# 96:  Then the LORD saw that the wickedness of man was great upon the earth, and that he
# breaking because  he !=  every
#
# 97:  Then the LORD saw that the wickedness of man was great upon the earth:
# breaking because : != ,
#
# 98:  Then the LORD saw that the wickedness of man was great upon the earth, and that he
# breaking because  he !=  every
#
# 99:  Then the LORD saw that the wickedness of man was great upon the earth, and that he
# breaking because  he !=  every
#
#
# Working on verse [GEN 6:6_a][GEN 6:6_b] And the LORD regretted that He had made man on the earth, and He was grieved in His heart.
#
# 0:  a
# breaking because  a !=  And
#
# 1:
#
# breaking because
#  !=  And
#
# 2:
#
# breaking because
#  !=  And
#
# 3:
#
# breaking because
#  !=  And
#
# 4:
#
# breaking because
#  !=  And
#
# 5:
#
# breaking because
#  !=  And
#
# 6:
#
# breaking because
#  !=  And
#
# 7:
#
# breaking because
#  !=  And
#
# 8:
#
# breaking because
#  !=  And
#
# 9:
#
# breaking because
#  !=  And
#
# 10:  And I
# breaking because  I !=  the
#
# 11:  And the The
# breaking because  The !=  LORD
#
# 12:
#
# breaking because
#  !=  And
#
# 13:  And
#
# breaking because
#  !=  the
#
# 14:  And the other
# breaking because  other !=  LORD
#
# 15:  And the other
# breaking because  other !=  LORD
#
# 16:  And the other
# breaking because  other !=  LORD
#
# 17:  And the whole
# breaking because  whole !=  LORD
#
# 18:  And the LORD of
# breaking because  of !=  regretted
#
# 19:  And the LORD of
# breaking because  of !=  regretted
#
# 20:  And,
# breaking because , !=  the
#
# 21:  And the Jews
# breaking because  Jews !=  LORD
#
# 22:  And the LORD of
# breaking because  of !=  regretted
#
# 23:  And the the
# breaking because  the !=  LORD
#
# 24:  And the the
# breaking because  the !=  LORD
#
# 25:  And the first
# breaking because  first !=  LORD
#
# 26:  And the LORD said
# breaking because  said !=  regretted
#
# 27:  And the LORD said
# breaking because  said !=  regretted
#
# 28:  And the LORD said
# breaking because  said !=  regretted
#
# 29:  And the LORD said
# breaking because  said !=  regretted
#
# 30:  And for
# breaking because  for !=  the
#
# 31:
#
# breaking because
#  !=  And
#
# 32:  And the LORD said
# breaking because  said !=  regretted
#
# 33:  And the LORD said
# breaking because  said !=  regretted
#
# 34:  And the LORD took
# breaking because  took !=  regretted
#
# 35:  And the whole
# breaking because  whole !=  LORD
#
# 36:  And the people
# breaking because  people !=  LORD
#
# 37:  And the LORD of
# breaking because  of !=  regretted
#
# 38:  And the LORD of
# breaking because  of !=  regretted
#
# 39:  And the LORD of
# breaking because  of !=  regretted
#
# 40:  And the LORD had
# breaking because  had !=  regretted
#
# 41:  And the LORD regretted.
# breaking because . !=  that
#
# 42:  And the LORD regretted the
# breaking because  the !=  that
#
# 43:  And the LORD regretted the
# breaking because  the !=  that
#
# 44:  And the LORD regretted that the
# breaking because  the !=  He
#
# 45:  And the LORD regretted the
# breaking because  the !=  that
#
# 46:  And the LORD regretted that he
# breaking because  he !=  He
#
# 47:  And the LORD regretted that he
# breaking because  he !=  He
#
# 48:  And the LORD regretted that he
# breaking because  he !=  He
#
# 49:  And the LORD regretted.
# breaking because . !=  that
#
# 50:  And the people
# breaking because  people !=  LORD
#
# 51:  And the LORD of
# breaking because  of !=  regretted
#
# 52:  And the LORD regretted that he
# breaking because  he !=  He
#
# 53:  And the LORD regretted that he
# breaking because  he !=  He
#
# 54:  And the LORD regretted that he
# breaking because  he !=  He
#
# 55:  And the LORD regretted that He had taken
# breaking because  taken !=  made
#
# 56:  And the LORD regretted that He had taken
# breaking because  taken !=  made
#
# 57:  And the LORD regretted that He had made war
# breaking because  war !=  man
#
# 58:  And the LORD regretted that He had made them
# breaking because  them !=  man
#
# 59:  And the LORD regretted that He had made man with
# breaking because  with !=  on
#
# 60:  And the LORD regretted that He had made man with
# breaking because  with !=  on
#
# 61:  And the LORD regretted that He had made man with
# breaking because  with !=  on
#
# 62:  And the LORD regretted that He had made man with
# breaking because  with !=  on
#
# 63:  And the LORD regretted that He had made man for
# breaking because  for !=  on
#
# 64:  And the LORD regretted that He had made man with
# breaking because  with !=  on
#
# 65:  And the LORD regretted that He had made man for
# breaking because  for !=  on
#
# 66:  And the LORD regretted that He had made man on the right
# breaking because  right !=  earth
#
# 67:  And the LORD had
# breaking because  had !=  regretted
#
# 68:  And the LORD regretted that he
# breaking because  he !=  He
#
# 69:  And the LORD God
# breaking because  God !=  regretted
#
# 70:  And the LORD regretted that he
# breaking because  he !=  He
#
# 71:  And Lord
# breaking because  Lord !=  the
#
# 72:  And the LORD regretted that He had made man with
# breaking because  with !=  on
#
#